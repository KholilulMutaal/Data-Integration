# %%
import pandas as pd
import numpy as np
Data1=pd.read_csv("D:\Documents\Kuliah\SEMESTER 6\DATA MINING\Tugas 1 (Data Integration)\Data school 1.csv")
Data2=pd.read_csv("D:\Documents\Kuliah\SEMESTER 6\DATA MINING\Tugas 1 (Data Integration)\Data school 2.csv")

Data_complete=pd.merge(Data1,Data2,on='School')

# %%
print (Data_complete)
# Out:
#                                   School  Enrollment  Cost/Pupil  AveTeach$  \
# 0                               Abington         563        7243      45833
# 1              Acton-Boxborough Regional        1490        6720      49260
# 2                     Algonquin Regional        1056        8070      47871
# 3                               Amesbury         796        6385      38913
# 4                                Andover        1626        6694      49402
# 5                              Arlington        1059        7688      45039
# 6                                Ashland         587        9160      42551
# 7                              Attleboro        1549        5882      40582
# 8                                   Avon         469        8757      32067
# 9                                Bedford         671        9167      49858
# 10                               Belmont         979        6264      52003
# ...

# %%
Data3=pd.read_csv("D:\Documents\Kuliah\SEMESTER 6\DATA MINING\Tugas 1 (Data Integration)\Data school 3.csv")
Data4=pd.read_csv("D:\Documents\Kuliah\SEMESTER 6\DATA MINING\Tugas 1 (Data Integration)\Data school 4.csv")

# %%
Data_complete2=pd.concat([Data3,Data4])
print (Data_complete2)
# Out:
#                                  School  Enrollment  Cost/Pupil  AveTeach$  \
# 0                              Abington         563        7243      45833
# 1             Acton-Boxborough Regional        1490        6720      49260
# 2                    Algonquin Regional        1056        8070      47871
# 3                              Amesbury         796        6385      38913
# 4                               Andover        1626        6694      49402
# 5                             Arlington        1059        7688      45039
# 6                               Ashland         587        9160      42551
# 7                             Attleboro        1549        5882      40582
# 8                                  Avon         469        8757      32067
# 9                               Bedford         671        9167      49858
# 10                              Belmont         979        6264      52003
# ...
